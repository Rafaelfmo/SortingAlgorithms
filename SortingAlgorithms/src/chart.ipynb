# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\Rafael Oliveira\\Desktop\\AV2\\merge_sort_serial.csv")

plt.plot(data['Tamanho'], data['Tempo'])
plt.xlabel('Tamanho')
plt.ylabel('Tempo')
plt.title('Merge Sort Serial')
plt.show()

# %%
data = pd.read_csv("C:\\Users\\Rafael Oliveira\\Desktop\\AV2\\merge_sort_paralelo.csv", sep=',')

data['Tempo'] = data.groupby(['Tamanho', 'Threads'])['Tempo'].transform('mean')

for threads in data['Threads'].unique():
    plt.plot(data[data['Threads'] == threads]['Tamanho'], data[data['Threads'] == threads]['Tempo'], label=f'{threads} Threads')


plt.xlabel('Tamanho')
plt.ylabel('Tempo')
plt.title('Merge Sort Paralelo')
plt.legend()


plt.grid(True)
plt.show()

# plt.ylim(0, 100000000)

# %%
data = pd.read_csv("C:\\Users\\Rafael Oliveira\\Desktop\\AV2\\parallel_insertion_sort.csv", sep=',')

data['Tempo'] = data.groupby(['Tamanho', 'Threads'])['Tempo'].transform('mean')

for threads in data['Threads'].unique():
    plt.plot(data[data['Threads'] == threads]['Tamanho'], data[data['Threads'] == threads]['Tempo'], label=f'{threads} Threads')


plt.xlabel('Tamanho')
plt.ylabel('Tempo')
plt.title('Insertition Sort Paralelo')
plt.legend()
plt.show()

# %%
data = pd.read_csv("C:\\Users\\Rafael Oliveira\\Desktop\\AV2\\serial_insertion_sort.csv", sep=',')

data['Tempo'] = data.groupby(['Tamanho'])['Tempo'].transform('mean')

plt.plot(data['Tamanho'], data['Tempo'])
plt.xlabel('Tamanho')
plt.ylabel('Tempo')
plt.title('Insertion Sort Serial')
plt.show()

# %%
data = pd.read_csv("C:\\Users\\Rafael Oliveira\\Desktop\\AV2\\bubble_sort_paralelo.csv", sep=',')

data['Tempo'] = data.groupby(['Tamanho'])['Tempo'].transform('mean')

plt.plot(data['Tamanho'], data['Tempo'])
plt.xlabel('Tamanho')
plt.ylabel('Tempo')
plt.title('Bubble Sort Paralelo')
plt.show()

# %%
data = pd.read_csv("C:\\Users\\Rafael Oliveira\\Desktop\\AV2\\bubble_sort_serial.csv", sep=',')

data['Tempo'] = data.groupby(['Tamanho'])['Tempo'].transform('mean')

plt.plot(data['Tamanho'], data['Tempo'])
plt.xlabel('Tamanho')
plt.ylabel('Tempo')
plt.title('Bubble Sort Serial')
plt.show()

# %%
data = pd.read_csv("C:\\Users\\Rafael Oliveira\\Desktop\\AV2\\quick_sort_paralelo.csv", sep=',')

data['Tempo'] = data.groupby(['Tamanho'])['Tempo'].transform('mean')

plt.plot(data['Tamanho'], data['Tempo'])
plt.xlabel('Tamanho')
plt.ylabel('Tempo')
plt.title('Quick Sort Paralelo')
plt.show()

# %%
data = pd.read_csv("C:\\Users\\Rafael Oliveira\\Desktop\\AV2\\quick_sort_serial.csv", sep=',')
data['Tempo'] = data.groupby(['Tamanho'])['Tempo'].transform('mean')

plt.plot(data['Tamanho'], data['Tempo'])
plt.xlabel('Tamanho')
plt.ylabel('Tempo')
plt.title('Quick Sort Serial')
plt.show()
